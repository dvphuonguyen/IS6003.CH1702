# %% [markdown]
# # Installation

# %%
# !git clone https://github.com/liaorongfan/DeepPersonality.git

# %%
import os
os.chdir("/content/DeepPersonality")
# !pip install -r requirements.txt

# %% [markdown]
# # Prepare data

# %%
# !pwd
# !gdown 1eANtFzA75Mqv01nW45exfauAIMLNO70J --output ChaLearn2016_tiny_processed.zip
# Out:
# /content/DeepPersonality
# Downloading...
# From: https://drive.google.com/uc?id=1eANtFzA75Mqv01nW45exfauAIMLNO70J
# To: /content/DeepPersonality/ChaLearn2016_tiny_processed.zip
# 100% 1.59G/1.59G [00:08<00:00, 193MB/s]

# %%
# !unzip ChaLearn2016_tiny_processed.zip -d datasets

# %% [markdown]
# # Train your own model
# If you have designed your own model and want to conduct an experiment on it. Base on the DeepPersonality code base, there are only two steps need to be bone.
# 1. Register your model
# 2. Modify default configration

# %% [markdown]
# ## Register your model
#
# The designed model can be `registered` by a `decorater` named `NETWORK_REGISTRY`, shown as below.
# >To acturally run the following demo model, you should create a python script `xx_net.py` and copy the code snap into it. And then `import` the it in `__init__.py` file.
#
# For the demonstration VGG model, it is copied into a file named `demo_model.py` under directory `dpcv/modeling/networks`, and imported in file `dpcv/modeling/networks/__init__.py`

# %%
# dpcv/modeling/networks
# demo_model.py
import torch
import torchvision.models as models
from dpcv.modeling.networks.build import NETWORK_REGISTRY


@NETWORK_REGISTRY.register()
def demo_model(args=None):
    model = models.vgg16(num_classes=5)
    model = model.to(
        device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
    )
    return model

# %%
# dpcv/modeling/networks/__init__.py
import dpcv.modeling.networks.demo_model

# %% [markdown]
# ## Modify default configration

# %% [markdown]
# There are different `data_loader` and `modal_trainer` to meet the requirements from different model inputs. Take the demo experiments we used for example, it employ bimodal_renet18 network whch takes audio and visual data as input. While the vgg model only takes visual data as input, we should change the `data_loader` and `modal_trainer` as follows.

# %%
demo_model = demo_model()
demo_model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=5, bias=True)
#   )
# )

# %%
# !python script/run_exp.py \
    -c config/demo/bimodal_resnet18.yaml \
    --set MODEL.NAME demo_model\
    DATA_LOADER.NAME single_frame_data_loader \
    TRAIN.TRAINER ImageModalTrainer \
    TRAIN.OUTPUT_DIR results/demo_model
# Out:
# {
#     "DATA":{
#         "ROOT":"datasets",
#         "SESSION":"talk",
#         "TEST_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/test_data",
#         "TEST_IMG_DATA":"ChaLearn2016_tiny/test_data",
#         "TEST_IMG_FACE_DATA":"image_data/test_data_face",
#         "TEST_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_test.pkl",
#         "TRAIN_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/train_data",
#         "TRAIN_IMG_DATA":"ChaLearn2016_tiny/train_data",
#         "TRAIN_IMG_FACE_DATA":"image_data/train_data_face",
#         "TRAIN_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_training.pkl",
#         "TYPE":"frame",
#         "VALID_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/valid_data",
#         "VALID_IMG_DATA":"ChaLearn2016_tiny/valid_data",
#         "VALID_IMG_FACE_DATA":"image_data/valid_data_face",
#         "VALID_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_validation.pkl",
#         "VA_DATA":"va_data/cropped_aligned",
#         "VA_ROOT":"datasets",
#         "VA_TRAIN_LABEL":"va_data/va_label/VA_Set/Train_Set",
#         "VA_VALID_LABEL":"va_data/va_label/VA_Set/Validation_Set"
#     },
#     "DATA_LOADER":{
#         "DATASET":"",
#         "DROP_LAST":true,
#         "NAME":"single_frame_data_loader",
#         "NUM_WORKERS":0,
#         "SECOND_STAGE":{
#             "METHOD":"",
#             "TYPE":""
#         },
#         "SHUFFLE":true,
#         "TRAIN_BATCH_SIZE":8,
#         "TRANSFORM":"standard_frame_transform",
#         "VALID_BATCH_SIZE":4
#     },
#     "LOSS":{
#         "NAME":"mean_square_error"
#     },
#     "MODEL":{
#         "NAME":"demo_model",
#         "NUM_CLASS":5,
#         "PRETRAIN":false,
#         "RETURN_FEATURE":false,
#         "SPECTRUM_CHANNEL":50
#     },
#     "SOLVER":{
#         "BETA_1":0.5,
#         "BETA_2":0.999,
#         "FACTOR":0.1,
#         "LR_INIT":0.001,
#         "MILESTONE":[
#             100,
#             200
#         ],
#         "MOMENTUM":0.9,
#         "NAME":"sgd",
#         "RESET_LR":false,
#         "SCHEDULER":"multi_step_scale",
#         "WEIGHT_DECAY":0.0005
#     },
#     "TEST":{
#         "COMPUTE_CCC":true,
#         "COMPUTE_PCC":true,
#         "FULL_TEST":false,
#         "SAVE_DATASET_OUTPUT":"",
#         "TEST_ONLY":false,
#         "WEIGHT":""
#     },
#     "TRAIN":{
#         "LOG_INTERVAL":10,
#         "MAX_EPOCH":30,
#         "OUTPUT_DIR":"results/demo_model",
#         "PRE_TRAINED_MODEL":null,
#         "RESUME":"",
#         "START_EPOCH":0,
#         "TRAINER":"ImageModalTrainer",
#         "VALID_INTERVAL":1
#     }
# }
# Training: learning rate:0.001
# Valid: Epoch[001/030] Train Mean_Acc: 63.07% Valid Mean_Acc:84.18% OCEAN_ACC:[0.8758023  0.84921485 0.8475549  0.8161581  0.82002074]
#
# Training: learning rate:0.001
# Valid: Epoch[002/030] Train Mean_Acc: 80.80% Valid Mean_Acc:88.42% OCEAN_ACC:[0.89325976 0.87368965 0.87499696 0.90984434 0.86944646]
#
# Training: learning rate:0.001
# Valid: Epoch[003/030] Train Mean_Acc: 83.62% Valid Mean_Acc:86.81% OCEAN_ACC:[0.8813103  0.8544993  0.85803825 0.8808219  0.8658201 ]
#
# Training: learning rate:0.001
# Valid: Epoch[004/030] Train Mean_Acc: 84.91% Valid Mean_Acc:88.52% OCEAN_ACC:[0.90693074 0.87332886 0.87087435 0.8987631  0.8761628 ]
#
# Training: learning rate:0.001
# Valid: Epoch[005/030] Train Mean_Acc: 84.36% Valid Mean_Acc:86.48% OCEAN_ACC:[0.88281155 0.84781677 0.85427016 0.8779454  0.86124134]
#
# Training: learning rate:0.001
# Valid: Epoch[006/030] Train Mean_Acc: 85.49% Valid Mean_Acc:87.64% OCEAN_ACC:[0.89672923 0.8677203  0.86620396 0.886641   0.8644984 ]
#
# Training: learning rate:0.001
# Valid: Epoch[007/030] Train Mean_Acc: 85.13% Valid Mean_Acc:87.96% OCEAN_ACC:[0.89762086 0.8646379  0.8740545  0.88986564 0.8717189 ]
#
# Training: learning rate:0.001
# Valid: Epoch[008/030] Train Mean_Acc: 85.52% Valid Mean_Acc:87.70% OCEAN_ACC:[0.8936713  0.8641359  0.8695679  0.8859701  0.87157726]
#
# Training: learning rate:0.001
# Valid: Epoch[009/030] Train Mean_Acc: 84.81% Valid Mean_Acc:86.75% OCEAN_ACC:[0.8789683  0.8527443  0.86028767 0.88216907 0.8633006 ]
#
# Training: learning rate:0.001
# Valid: Epoch[010/030] Train Mean_Acc: 84.26% Valid Mean_Acc:87.88% OCEAN_ACC:[0.89770895 0.8743256  0.86442024 0.88513404 0.8722117 ]
#
# Training: learning rate:0.001
# Valid: Epoch[011/030] Train Mean_Acc: 86.14% Valid Mean_Acc:88.79% OCEAN_ACC:[0.8882043  0.87470454 0.88208055 0.9076503  0.8866243 ]
#
# Training: learning rate:0.001
# Valid: Epoch[012/030] Train Mean_Acc: 86.46% Valid Mean_Acc:88.52% OCEAN_ACC:[0.90583634 0.87971383 0.87147576 0.8916552  0.8771251 ]
#
# Training: learning rate:0.001
# Valid: Epoch[013/030] Train Mean_Acc: 86.31% Valid Mean_Acc:88.96% OCEAN_ACC:[0.9101369  0.87252027 0.87970304 0.8977232  0.88808155]
#
# Training: learning rate:0.001
# Valid: Epoch[014/030] Train Mean_Acc: 86.59% Valid Mean_Acc:88.78% OCEAN_ACC:[0.9038113  0.8793017  0.876163   0.89447236 0.88501525]
#
# Training: learning rate:0.001
# Valid: Epoch[015/030] Train Mean_Acc: 85.96% Valid Mean_Acc:89.02% OCEAN_ACC:[0.910353   0.8751073  0.87722903 0.90196127 0.88621134]
#
# Training: learning rate:0.001
# Valid: Epoch[016/030] Train Mean_Acc: 87.21% Valid Mean_Acc:88.66% OCEAN_ACC:[0.9029312  0.88236004 0.8774139  0.89303994 0.87718266]
#
# Training: learning rate:0.001
# Valid: Epoch[017/030] Train Mean_Acc: 86.89% Valid Mean_Acc:87.27% OCEAN_ACC:[0.88716966 0.85801053 0.86243373 0.8834645  0.87231827]
#
# Training: learning rate:0.001
# Valid: Epoch[018/030] Train Mean_Acc: 86.92% Valid Mean_Acc:88.21% OCEAN_ACC:[0.9054649  0.8758748  0.86998576 0.88437146 0.8747155 ]
#
# Training: learning rate:0.001
# Valid: Epoch[019/030] Train Mean_Acc: 85.91% Valid Mean_Acc:89.06% OCEAN_ACC:[0.9115896  0.87402016 0.87889385 0.89987564 0.8886159 ]
#
# Training: learning rate:0.001
# Valid: Epoch[020/030] Train Mean_Acc: 87.22% Valid Mean_Acc:89.12% OCEAN_ACC:[0.9102705 0.8817177 0.8821039 0.8927946 0.8890012]
#
# Training: learning rate:0.001
# Valid: Epoch[021/030] Train Mean_Acc: 87.62% Valid Mean_Acc:89.13% OCEAN_ACC:[0.9113879  0.8804106  0.87726575 0.8976531  0.890016  ]
#
# Training: learning rate:0.001
# Valid: Epoch[022/030] Train Mean_Acc: 87.06% Valid Mean_Acc:89.15% OCEAN_ACC:[0.9135272  0.87883836 0.8811342  0.8959803  0.88794136]
#
# Training: learning rate:0.001
# Valid: Epoch[023/030] Train Mean_Acc: 87.09% Valid Mean_Acc:88.74% OCEAN_ACC:[0.90778154 0.87898725 0.8777688  0.88756007 0.88473564]
#
# Training: learning rate:0.001
# Valid: Epoch[024/030] Train Mean_Acc: 87.72% Valid Mean_Acc:89.18% OCEAN_ACC:[0.9107987  0.8821166  0.88228303 0.8941896  0.8894067 ]
#
# Training: learning rate:0.001
# Valid: Epoch[025/030] Train Mean_Acc: 87.71% Valid Mean_Acc:87.54% OCEAN_ACC:[0.89462024 0.86535597 0.8664458  0.87831193 0.8720531 ]
#
# Training: learning rate:0.001
# Valid: Epoch[026/030] Train Mean_Acc: 87.79% Valid Mean_Acc:88.49% OCEAN_ACC:[0.9079313  0.87113076 0.87630326 0.88674384 0.88245684]
#
# Training: learning rate:0.001
# Valid: Epoch[027/030] Train Mean_Acc: 87.29% Valid Mean_Acc:88.38% OCEAN_ACC:[0.9087928  0.871522   0.8728843  0.8848893  0.88092345]
#
# Training: learning rate:0.001
# Valid: Epoch[028/030] Train Mean_Acc: 87.36% Valid Mean_Acc:89.01% OCEAN_ACC:[0.91027325 0.88009995 0.88233966 0.8930151  0.8849729 ]
#
# Training: learning rate:0.001
# Valid: Epoch[029/030] Train Mean_Acc: 87.84% Valid Mean_Acc:89.08% OCEAN_ACC:[0.9156423  0.87904644 0.88072807 0.891865   0.8864799 ]
#
# Training: learning rate:0.001
# Valid: Epoch[030/030] Train Mean_Acc: 88.03% Valid Mean_Acc:87.90% OCEAN_ACC:[0.9005368 0.8683618 0.8688285 0.8821278 0.8751357]
#
# 10-07_23-52 done, best acc: 0.891758918762207 in :23
# Test only mode
# test with model results/demo_model\10-07_23-51\checkpoint_23.pkl
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:00<00:00,  5.30it/s]
#  67%|██████▋   | 2/3 [00:00<00:00,  5.29it/s]
# 100%|██████████| 3/3 [00:00<00:00,  6.29it/s]
# mse: {'O': 0.0181, 'C': 0.0215, 'E': 0.024, 'A': 0.0268, 'N': 0.0356} mean: 0.025200000032782555
# acc: {'O': 0.8952, 'C': 0.8841, 'E': 0.8712, 'A': 0.8626, 'N': 0.8579} mean: 0.8742
# pcc: {'O': 0.0818, 'C': 0.0816, 'E': -0.1682, 'A': -0.1568, 'N': -0.1233} mean: -0.057
# ccc: {'O': 0.0729, 'C': 0.0652, 'E': -0.1374, 'A': -0.1254, 'N': -0.0899} mean: -0.0429

# %%
# !python script/run_exp.py -c config/demo/add_user_model_vgg.yaml
# Out:
# {
#     "DATA":{
#         "ROOT":"datasets",
#         "SESSION":"talk",
#         "TEST_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/test_data",
#         "TEST_IMG_DATA":"ChaLearn2016_tiny/test_data",
#         "TEST_IMG_FACE_DATA":"image_data/test_data_face",
#         "TEST_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_test.pkl",
#         "TRAIN_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/train_data",
#         "TRAIN_IMG_DATA":"ChaLearn2016_tiny/train_data",
#         "TRAIN_IMG_FACE_DATA":"image_data/train_data_face",
#         "TRAIN_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_training.pkl",
#         "TYPE":"frame",
#         "VALID_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/valid_data",
#         "VALID_IMG_DATA":"ChaLearn2016_tiny/valid_data",
#         "VALID_IMG_FACE_DATA":"image_data/valid_data_face",
#         "VALID_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_validation.pkl",
#         "VA_DATA":"va_data/cropped_aligned",
#         "VA_ROOT":"datasets",
#         "VA_TRAIN_LABEL":"va_data/va_label/VA_Set/Train_Set",
#         "VA_VALID_LABEL":"va_data/va_label/VA_Set/Validation_Set"
#     },
#     "DATA_LOADER":{
#         "DATASET":"",
#         "DROP_LAST":true,
#         "NAME":"single_frame_data_loader",
#         "NUM_WORKERS":0,
#         "SECOND_STAGE":{
#             "METHOD":"",
#             "TYPE":""
#         },
#         "SHUFFLE":true,
#         "TRAIN_BATCH_SIZE":8,
#         "TRANSFORM":"standard_frame_transform",
#         "VALID_BATCH_SIZE":4
#     },
#     "LOSS":{
#         "NAME":"mean_square_error"
#     },
#     "MODEL":{
#         "NAME":"demo_model",
#         "NUM_CLASS":5,
#         "PRETRAIN":false,
#         "RETURN_FEATURE":false,
#         "SPECTRUM_CHANNEL":50
#     },
#     "SOLVER":{
#         "BETA_1":0.5,
#         "BETA_2":0.999,
#         "FACTOR":0.1,
#         "LR_INIT":0.001,
#         "MILESTONE":[
#             100,
#             200
#         ],
#         "MOMENTUM":0.9,
#         "NAME":"sgd",
#         "RESET_LR":false,
#         "SCHEDULER":"multi_step_scale",
#         "WEIGHT_DECAY":0.0005
#     },
#     "TEST":{
#         "COMPUTE_CCC":true,
#         "COMPUTE_PCC":true,
#         "FULL_TEST":false,
#         "SAVE_DATASET_OUTPUT":"",
#         "TEST_ONLY":false,
#         "WEIGHT":""
#     },
#     "TRAIN":{
#         "LOG_INTERVAL":10,
#         "MAX_EPOCH":30,
#         "OUTPUT_DIR":"results/demo/vgg16",
#         "PRE_TRAINED_MODEL":null,
#         "RESUME":"",
#         "START_EPOCH":0,
#         "TRAINER":"ImageModalTrainer",
#         "VALID_INTERVAL":1
#     }
# }
# Training: learning rate:0.001
# Valid: Epoch[001/030] Train Mean_Acc: 59.09% Valid Mean_Acc:88.04% OCEAN_ACC:[0.8710041  0.863878   0.87036896 0.90770596 0.88917255]
#
# Training: learning rate:0.001
# Valid: Epoch[002/030] Train Mean_Acc: 77.45% Valid Mean_Acc:87.04% OCEAN_ACC:[0.84924704 0.84275085 0.874724   0.90764874 0.87783605]
#
# Training: learning rate:0.001
# Valid: Epoch[003/030] Train Mean_Acc: 78.28% Valid Mean_Acc:84.24% OCEAN_ACC:[0.82011396 0.82525486 0.8390952  0.8844102  0.84324116]
#
# Training: learning rate:0.001
# Valid: Epoch[004/030] Train Mean_Acc: 82.17% Valid Mean_Acc:85.83% OCEAN_ACC:[0.8847305 0.8643584 0.8522334 0.8386183 0.8513418]
#
# Training: learning rate:0.001
# Valid: Epoch[005/030] Train Mean_Acc: 83.35% Valid Mean_Acc:86.79% OCEAN_ACC:[0.86482596 0.84520894 0.8733161  0.88557893 0.8704235 ]
#
# Training: learning rate:0.001
# Valid: Epoch[006/030] Train Mean_Acc: 85.83% Valid Mean_Acc:85.33% OCEAN_ACC:[0.87776256 0.8517716  0.84278136 0.8484471  0.8459845 ]
#
# Training: learning rate:0.001
# Valid: Epoch[007/030] Train Mean_Acc: 85.19% Valid Mean_Acc:87.73% OCEAN_ACC:[0.8939924  0.8670381  0.87239504 0.87739664 0.87572575]
#
# Training: learning rate:0.001
# Valid: Epoch[008/030] Train Mean_Acc: 84.80% Valid Mean_Acc:86.90% OCEAN_ACC:[0.86124015 0.8568421  0.87146354 0.8853428  0.8702795 ]
#
# Training: learning rate:0.001
# Valid: Epoch[009/030] Train Mean_Acc: 84.51% Valid Mean_Acc:87.15% OCEAN_ACC:[0.89741325 0.8657639  0.865292   0.8672328  0.861974  ]
#
# Training: learning rate:0.001
# Valid: Epoch[010/030] Train Mean_Acc: 85.62% Valid Mean_Acc:87.67% OCEAN_ACC:[0.8877783  0.85969883 0.87449795 0.88718003 0.8743357 ]
#
# Training: learning rate:0.001
# Valid: Epoch[011/030] Train Mean_Acc: 85.89% Valid Mean_Acc:86.15% OCEAN_ACC:[0.8782763  0.85082227 0.8550448  0.86245185 0.8611248 ]
#
# Training: learning rate:0.001
# Valid: Epoch[012/030] Train Mean_Acc: 85.77% Valid Mean_Acc:88.59% OCEAN_ACC:[0.8921091  0.87840253 0.8832875  0.88815594 0.8874502 ]
#
# Training: learning rate:0.001
# Valid: Epoch[013/030] Train Mean_Acc: 86.04% Valid Mean_Acc:88.36% OCEAN_ACC:[0.88676006 0.87415856 0.88147336 0.89660174 0.8788114 ]
#
# Training: learning rate:0.001
# Valid: Epoch[014/030] Train Mean_Acc: 85.96% Valid Mean_Acc:88.19% OCEAN_ACC:[0.90432334 0.8722172  0.873648   0.8786349  0.8807258 ]
#
# Training: learning rate:0.001
# Valid: Epoch[015/030] Train Mean_Acc: 85.27% Valid Mean_Acc:88.21% OCEAN_ACC:[0.903671   0.87289673 0.87118286 0.8829338  0.8799451 ]
#
# Training: learning rate:0.001
# Valid: Epoch[016/030] Train Mean_Acc: 85.35% Valid Mean_Acc:87.91% OCEAN_ACC:[0.89906406 0.86133224 0.87212735 0.88412046 0.87908965]
#
# Training: learning rate:0.001
# Valid: Epoch[017/030] Train Mean_Acc: 85.54% Valid Mean_Acc:87.87% OCEAN_ACC:[0.90250975 0.86928576 0.87251925 0.8762179  0.87306976]
#
# Training: learning rate:0.001
# Valid: Epoch[018/030] Train Mean_Acc: 86.41% Valid Mean_Acc:87.69% OCEAN_ACC:[0.88873863 0.8662874  0.8714836  0.8830126  0.875191  ]
#
# Training: learning rate:0.001
# Valid: Epoch[019/030] Train Mean_Acc: 85.78% Valid Mean_Acc:88.28% OCEAN_ACC:[0.9022293  0.87192583 0.8756251  0.88423723 0.8802183 ]
#
# Training: learning rate:0.001
# Valid: Epoch[020/030] Train Mean_Acc: 86.15% Valid Mean_Acc:87.85% OCEAN_ACC:[0.8910349  0.8682777  0.8713209  0.8841582  0.87783545]
#
# Training: learning rate:0.001
# Valid: Epoch[021/030] Train Mean_Acc: 86.64% Valid Mean_Acc:87.84% OCEAN_ACC:[0.90351266 0.8742301  0.8676338  0.87657386 0.8699326 ]
#
# Training: learning rate:0.001
# Valid: Epoch[022/030] Train Mean_Acc: 85.76% Valid Mean_Acc:88.35% OCEAN_ACC:[0.8938249 0.8717807 0.8794961 0.8896697 0.8827229]
#
# Training: learning rate:0.001
# Valid: Epoch[023/030] Train Mean_Acc: 86.21% Valid Mean_Acc:88.40% OCEAN_ACC:[0.8961895  0.87166905 0.8770265  0.88970643 0.88556343]
#
# Training: learning rate:0.001
# Valid: Epoch[024/030] Train Mean_Acc: 87.50% Valid Mean_Acc:88.20% OCEAN_ACC:[0.90420586 0.87502766 0.87101907 0.88039565 0.8791612 ]
#
# Training: learning rate:0.001
# Valid: Epoch[025/030] Train Mean_Acc: 87.08% Valid Mean_Acc:88.35% OCEAN_ACC:[0.8938417  0.8726093  0.8766642  0.88765055 0.88651496]
#
# Training: learning rate:0.001
# Valid: Epoch[026/030] Train Mean_Acc: 85.93% Valid Mean_Acc:88.31% OCEAN_ACC:[0.900023   0.8714166  0.8725937  0.8874876  0.88374186]
#
# Training: learning rate:0.001
# Valid: Epoch[027/030] Train Mean_Acc: 86.68% Valid Mean_Acc:88.26% OCEAN_ACC:[0.8907261  0.8740838  0.8802044  0.8871843  0.88085127]
#
# Training: learning rate:0.001
# Valid: Epoch[028/030] Train Mean_Acc: 87.33% Valid Mean_Acc:86.88% OCEAN_ACC:[0.8898209  0.8615613  0.86208963 0.8699269  0.8607459 ]
#
# Training: learning rate:0.001
# Valid: Epoch[029/030] Train Mean_Acc: 85.84% Valid Mean_Acc:88.13% OCEAN_ACC:[0.89700085 0.86997753 0.8740649  0.88284916 0.882425  ]
#
# Training: learning rate:0.001
# Valid: Epoch[030/030] Train Mean_Acc: 85.94% Valid Mean_Acc:87.96% OCEAN_ACC:[0.8898158  0.8679177  0.87435645 0.8850255  0.8809114 ]
#
# 10-07_23-54 done, best acc: 0.8858810663223267 in :11
# Test only mode
# test with model results/demo/vgg16\10-07_23-53\checkpoint_11.pkl
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#  33%|███▎      | 1/3 [00:00<00:00,  7.90it/s]
#  67%|██████▋   | 2/3 [00:00<00:00,  8.38it/s]
# 100%|██████████| 3/3 [00:00<00:00,  9.88it/s]
# mse: {'O': 0.0195, 'C': 0.0221, 'E': 0.0263, 'A': 0.0276, 'N': 0.0386} mean: 0.026799999177455902
# acc: {'O': 0.8845, 'C': 0.8848, 'E': 0.8686, 'A': 0.8561, 'N': 0.8517} mean: 0.8691
# pcc: {'O': 0.011, 'C': 0.0928, 'E': -0.1874, 'A': -0.1382, 'N': -0.1548} mean: -0.0753
# ccc: {'O': 0.0094, 'C': 0.0781, 'E': -0.1572, 'A': -0.1215, 'N': -0.1216} mean: -0.0625

# %%
# !python script/run_exp.py \
#     -c config/demo/bimodal_resnet18.yaml \
#     --set MODEL.NAME demo_model\
#     DATA_LOADER.NAME single_frame_data_loader \
#     TRAIN.TRAINER ImageModalTrainer \
#     TRAIN.OUTPUT_DIR results/demo_model

# %% [markdown]
# And of course we can write those configration into a corresponding `yaml` config file, shown as below.
# ```
# # config/demo/add_user_model_vgg.yaml
# DATA:
#   ROOT: "datasets"
#   TRAIN_IMG_DATA: "ChaLearn2016_tiny/train_data"
#   VALID_IMG_DATA: "ChaLearn2016_tiny/valid_data"
#   TEST_IMG_DATA: "ChaLearn2016_tiny/test_data"
#   TRAIN_AUD_DATA: "ChaLearn2016_tiny/voice_data/voice_librosa/train_data"
#   VALID_AUD_DATA: "ChaLearn2016_tiny/voice_data/voice_librosa/valid_data"
#   TEST_AUD_DATA: "ChaLearn2016_tiny/voice_data/voice_librosa/test_data"
#   TRAIN_LABEL_DATA: "ChaLearn2016_tiny/annotation/annotation_training.pkl"
#   VALID_LABEL_DATA: "ChaLearn2016_tiny/annotation/annotation_validation.pkl"
#   TEST_LABEL_DATA: "ChaLearn2016_tiny/annotation/annotation_test.pkl"
# DATA_LOADER:
#   NAME: "single_frame_data_loader"
#   TRANSFORM: "standard_frame_transform"
#   TRAIN_BATCH_SIZE: 8
#   VALID_BATCH_SIZE: 4
#   NUM_WORKERS: 0
# MODEL:
#   NAME: "demo_model"
# LOSS:
#   NAME: "mean_square_error"
# SOLVER:
#   NAME: "sgd"
#   SCHEDULER: "multi_step_scale"
#   LR_INIT: 0.001
#   WEIGHT_DECAY: 0.0005
#   MOMENTUM: 0.9
#   MILESTONE: [100, 200]
# TRAIN:
#   TRAINER: "ImageModalTrainer"
#   MAX_EPOCH: 30
#   OUTPUT_DIR: "results/demo/vgg16"
#   ```
#   > To run the config file, create it in the code repo first.

# %%
# !python script/run_exp.py -c config/demo/add_user_model_vgg.yaml
# Out:
# Valid: Epoch[021/030] Train Mean_Acc: 86.45% Valid Mean_Acc:88.42% OCEAN_ACC:[0.8922451  0.87088394 0.88151866 0.8941389  0.8822897 ]
#
# INFO:log.log:Valid: Epoch[021/030] Train Mean_Acc: 86.45% Valid Mean_Acc:88.42% OCEAN_ACC:[0.8922451  0.87088394 0.88151866 0.8941389  0.8822897 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[022/030] Train Mean_Acc: 85.92% Valid Mean_Acc:88.64% OCEAN_ACC:[0.9040103 0.8766871 0.8838394 0.8911801 0.8765133]
#
# INFO:log.log:Valid: Epoch[022/030] Train Mean_Acc: 85.92% Valid Mean_Acc:88.64% OCEAN_ACC:[0.9040103 0.8766871 0.8838394 0.8911801 0.8765133]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[023/030] Train Mean_Acc: 86.63% Valid Mean_Acc:87.34% OCEAN_ACC:[0.89718133 0.86010647 0.86875945 0.8755515  0.865557  ]
#
# INFO:log.log:Valid: Epoch[023/030] Train Mean_Acc: 86.63% Valid Mean_Acc:87.34% OCEAN_ACC:[0.89718133 0.86010647 0.86875945 0.8755515  0.865557  ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[024/030] Train Mean_Acc: 86.24% Valid Mean_Acc:88.23% OCEAN_ACC:[0.8983269  0.871214   0.87719125 0.88826233 0.87636733]
#
# INFO:log.log:Valid: Epoch[024/030] Train Mean_Acc: 86.24% Valid Mean_Acc:88.23% OCEAN_ACC:[0.8983269  0.871214   0.87719125 0.88826233 0.87636733]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[025/030] Train Mean_Acc: 86.23% Valid Mean_Acc:87.07% OCEAN_ACC:[0.89261484 0.85741156 0.8659312  0.8731988  0.8645627 ]
#
# INFO:log.log:Valid: Epoch[025/030] Train Mean_Acc: 86.23% Valid Mean_Acc:87.07% OCEAN_ACC:[0.89261484 0.85741156 0.8659312  0.8731988  0.8645627 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[026/030] Train Mean_Acc: 86.98% Valid Mean_Acc:88.05% OCEAN_ACC:[0.9039521  0.8676689  0.8748622  0.8835587  0.87230855]
#
# INFO:log.log:Valid: Epoch[026/030] Train Mean_Acc: 86.98% Valid Mean_Acc:88.05% OCEAN_ACC:[0.9039521  0.8676689  0.8748622  0.8835587  0.87230855]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[027/030] Train Mean_Acc: 87.00% Valid Mean_Acc:88.44% OCEAN_ACC:[0.89211863 0.86859465 0.8832121  0.8915963  0.8863366 ]
#
# INFO:log.log:Valid: Epoch[027/030] Train Mean_Acc: 87.00% Valid Mean_Acc:88.44% OCEAN_ACC:[0.89211863 0.86859465 0.8832121  0.8915963  0.8863366 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[028/030] Train Mean_Acc: 87.57% Valid Mean_Acc:88.08% OCEAN_ACC:[0.90806437 0.872982   0.87774587 0.8757674  0.8695178 ]
#
# INFO:log.log:Valid: Epoch[028/030] Train Mean_Acc: 87.57% Valid Mean_Acc:88.08% OCEAN_ACC:[0.90806437 0.872982   0.87774587 0.8757674  0.8695178 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[029/030] Train Mean_Acc: 87.17% Valid Mean_Acc:87.92% OCEAN_ACC:[0.883441   0.86773115 0.8752454  0.8878608  0.8816362 ]
#
# INFO:log.log:Valid: Epoch[029/030] Train Mean_Acc: 87.17% Valid Mean_Acc:87.92% OCEAN_ACC:[0.883441   0.86773115 0.8752454  0.8878608  0.8816362 ]
#
# Training: learning rate:0.001
# INFO:log.log:Training: learning rate:0.001
# Valid: Epoch[030/030] Train Mean_Acc: 86.87% Valid Mean_Acc:87.55% OCEAN_ACC:[0.89870435 0.864111   0.8750262  0.8759957  0.8634917 ]
#
# INFO:log.log:Valid: Epoch[030/030] Train Mean_Acc: 86.87% Valid Mean_Acc:87.55% OCEAN_ACC:[0.89870435 0.864111   0.8750262  0.8759957  0.8634917 ]
#
# 11-10_17-11 done, best acc: 0.8937475085258484 in :1
# INFO:log.log:11-10_17-11 done, best acc: 0.8937475085258484 in :1
# Test only mode
# INFO:log.log:Test only mode
# test with model results/demo/vgg16/11-10_17-10/checkpoint_1.pkl
# INFO:log.log:test with model results/demo/vgg16/11-10_17-10/checkpoint_1.pkl
# 100% 3/3 [00:00<00:00,  8.82it/s]
# mse: {'O': 0.0225, 'C': 0.0228, 'E': 0.0256, 'A': 0.0306, 'N': 0.0395} mean: 0.028200000524520874
# INFO:log.log:mse: {'O': 0.0225, 'C': 0.0228, 'E': 0.0256, 'A': 0.0306, 'N': 0.0395} mean: 0.028200000524520874
# acc: {'O': 0.8688, 'C': 0.8758, 'E': 0.8706, 'A': 0.8484, 'N': 0.8367} mean: 0.8601
# INFO:log.log:acc: {'O': 0.8688, 'C': 0.8758, 'E': 0.8706, 'A': 0.8484, 'N': 0.8367} mean: 0.8601
# pcc: {'O': -0.0207, 'C': 0.0534, 'E': -0.2868, 'A': -0.2245, 'N': -0.2453} mean: -0.1448
# INFO:log.log:pcc: {'O': -0.0207, 'C': 0.0534, 'E': -0.2868, 'A': -0.2245, 'N': -0.2453} mean: -0.1448
# ccc: {'O': -0.019, 'C': 0.0419, 'E': -0.2507, 'A': -0.2042, 'N': -0.1927} mean: -0.125
# INFO:log.log:ccc: {'O': -0.019, 'C': 0.0419, 'E': -0.2507, 'A': -0.2042, 'N': -0.1927} mean: -0.125
